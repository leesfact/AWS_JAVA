# %%
import numpy as np
import pandas as pd

pd_hydrant = pd.read_csv('전국소방용수시설표준데이터.csv',encoding = 'cp949')
pd_parking = pd.read_csv('전국소방자동차전용구역표준데이터.csv',encoding = 'cp949')

#print(pd_hydrant.columns,pd_hydrant.shape)  # (50000,19)
#print(pd_parking.columns,pd_parking.shape)  #(3492,17)

col_selection = ['시도명','소재지도로명주소','위도','경도']
df1 = pd_hydrant[col_selection]
df2 = pd_parking[col_selection]

df_combined = pd.concat((df1,df2),keys=['hydrant','parking'])
#print(df_combined.shape)  #(53492 , 4)
df_combined.reset_index(inplace=True)
df_combined.drop('level_1', axis = 1, inplace=True)

cname_list = list(df_combined.columns)
cname_list[0] = '종류'
df_combined.columns = cname_list

df_combined
# Out:
#             종류    시도명                            소재지도로명주소         위도  \
# 0      hydrant  서울특별시  서울특별시 금천구 가산디지털2로 36 g밸리 더리브 스마트타워  37.471257
# 1      hydrant  서울특별시           서울특별시 금천구 가산디지털1로 171 수위실  37.481101
# 2      hydrant  서울특별시         서울특별시 금천구 두산로3길 49 가산동제2경노당  37.472620
# 3      hydrant  서울특별시               서울특별시 금천구 벚꽃로 208 경비실  37.473484
# 4      hydrant  서울특별시           서울특별시 금천구 가산디지털2로 169 수위실  37.482797
# ...        ...    ...                                 ...        ...
# 53487  parking  울산광역시          울산광역시 울주군 범서읍 백천2길 88(굴화리)  35.555881
# 53488  parking  울산광역시          울산광역시 울주군 범서읍 천상3길 11(천상리)  35.563268
# 53489  parking  울산광역시          울산광역시 울주군 범서읍 장검길 143(굴화리)  35.547636
# 53490  parking  울산광역시          울산광역시 울주군 범서읍 장검길 143(굴화리)  35.547636
# 53491  parking   전라북도                    전라북도 정읍시 첨단1로 47  35.507091
#
#                경도
# 0      126.882859
# 1      126.881118
# 2      126.888857
# 3      126.886718
# 4      126.877303
# ...           ...
# ...

# %%
g1 = df_combined.groupby(['시도명','종류'])
g1.count()

g2 = df_combined.groupby(['종류','시도명'])
g2.count()
# Out:
#                  소재지도로명주소     위도     경도
# 종류      시도명
# hydrant 대구광역시         130    130    130
#         부산광역시        6440   6440   6440
#         서울특별시       43430  43430  43430
# parking 강원도           243    243    243
#         경기도           284    281    264
#         경상남도          106    111    111
#         광주광역시           8      8      8
#         대구광역시           6      6      6
#         대전광역시          58     58     58
#         부산광역시          18     18     18
#         세종특별자치시         8      8      8
#         울산광역시        2368   2368   2368
#         인천광역시         126    171    171
#         전라남도           95     95     95
#         전라북도           32     32     32
#         제주특별자치도         1      1      1
#         충청남도           20     20     20
#         충청북도           68     68     68

# %%
df1 = f1[f1['시설유형코드'].fillna('hydrant') == 'hydrant'][['종류', '시도명', '소재지도로명주소', '위도', '경도']]
df2 = f2[f2['시군구명'].fillna('parking') == 'parking'][['종류', '시도명', '소재지도로명주소', '위도', '경도']]


print(df1.head())
print(df2.head())

#df12 = pd.concat((df1,df2), axis = 0)
#df12.reset_index(level = 0 , inplace=True)
#df12
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 df1 = f1[f1['시설유형코드'].fillna('hydrant') == 'hydrant'][['종류', '시도명', '소재지도로명주소', '위도', '경도']]
#       2 df2 = f2[f2['시군구명'].fillna('parking') == 'parking'][['종류', '시도명', '소재지도로명주소', '위도', '경도']]
#       5 print(df1.head())
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:3813, in DataFrame.__getitem__(self, key)
#    3811     if is_iterator(key):
#    3812         key = list(key)
# -> 3813     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3815 # take() does not accept boolean indexers
#    3816 if getattr(indexer, "dtype", None) == bool:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\base.py:6070, in Index._get_indexer_strict(self, key, axis_name)
#    6067 else:
# ...
