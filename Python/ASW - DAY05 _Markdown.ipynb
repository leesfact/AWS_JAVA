# %% [markdown]
# | hello     | h2      |
# |:-----|:------|
# |     v2 |vg       |
#
# # heading1
# ## heading2
# ### heading3
# #### heading4
# ***heading***
# *heading*
# heading
# ======
# heading
# ---------

# %% [markdown]
# 문장1 문장2 문장3
# 문장4
#
# 문단x
# <span style="background-color:indianred">빨간색</span>
# 📌
# - 가.
# - 나.
# - 다.
# - 라.
#
# ```java
# int a = 5;
# ```

# %% [markdown]
# $$
#  5 = 3+2
# $$

# %%
csv_data = []
with open('간이생명표.csv') as f:
    for i in f:
        #print(i)
        csv_data.append(i.split(','))
print(csv_data)
# Out:
# [['"시점"', '"항목"', '0\n'], ['"1970"', '"기대여명(전체) (년)"', '62.27305\n'], ['"1971"', '"기대여명(전체) (년)"', '62.69237\n'], ['"1972"', '"기대여명(전체) (년)"', '63.09909\n'], ['"1973"', '"기대여명(전체) (년)"', '63.49366\n'], ['"1974"', '"기대여명(전체) (년)"', '63.87659\n'], ['"1975"', '"기대여명(전체) (년)"', '64.24838\n'], ['"1976"', '"기대여명(전체) (년)"', '64.60943\n'], ['"1977"', '"기대여명(전체) (년)"', '64.96018\n'], ['"1978"', '"기대여명(전체) (년)"', '65.30103\n'], ['"1979"', '"기대여명(전체) (년)"', '65.63236\n'], ['"1980"', '"기대여명(전체) (년)"', '66.14746\n'], ['"1981"', '"기대여명(전체) (년)"', '66.66415\n'], ['"1982"', '"기대여명(전체) (년)"', '67.1674\n'], ['"1983"', '"기대여명(전체) (년)"', '67.65403\n'], ['"1984"', '"기대여명(전체) (년)"', '68.30106\n'], ['"1985"', '"기대여명(전체) (년)"', '68.91016\n'], ['"1986"', '"기대여명(전체) (년)"', '69.53312\n'], ['"1987"', '"기대여명(전체) (년)"', '70.12731\n'], ['"1988"', '"기대여명(전체) (년)"', '70.65048\n'], ['"1989"', '"기대여명(전체) (년)"', '71.15583\n'], ['"1990"', '"기대여명(전체) (년)"', '71.65935\n'], ['"1991"', '"기대여명(전체) (년)"', '72.15445\n'], ['"19
# ...
