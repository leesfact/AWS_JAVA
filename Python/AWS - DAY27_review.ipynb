# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
fig,axe = plt.subplots()
#axe.plot(np.linspace(-1.0,1.0,10),np.sin(np.linspace(-1,1.0,10))) # x, y 값

axe.plot(np.sin(np.linspace(-1.0,1.0,10)))

fig.set_facecolor('indianred')
axe.set_facecolor('#121212')

ax1 = fig.add_axes([0.2,0.5 , 0.2 , 0.3])
ax1.plot([1,2,4,8,16])

# %%
fig1 =plt.figure(layout ='tight')
fig1.add_subplot(1,3,1)

fig1.add_subplot(2,3,5)
# Out:
# <Axes: >

# %%
fig1 =plt.figure(layout ='tight')
fig1.add_subplot(3,2,1)
fig1.add_subplot(3,2,2)
fig1.add_subplot(3,1,2)
fig1.add_subplot(3,1,3)
# Out:
# <Axes: >
