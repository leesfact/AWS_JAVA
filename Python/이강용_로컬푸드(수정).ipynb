# %%
import numpy as np
import math

def my_split(s):
    block_start = False
    start_index = 0
    ret_list=[]
    for i, c in enumerate(s):
        if block_start==False:
            if c==',':
                ret_list.append(s[start_index:i])
                start_index=i+1
            elif c=='"':
                block_start=True
                start_index = i
        else:
            if c=='"':
                block_start=False
    if s[-1]!=',':
        ret_list.append(s[start_index:])
    return ret_list

def split_len(data_list):
    len_list=[]
    for e in data_list:
        len_list.append(len(e))
    print(set(len_list))
    if len(set(len_list))>1:
        for i in set(len_list):
            print(i, len_list.count(i))

# %%
csv_data = []
with open('전국로컬푸드인증정보표준데이터.csv',encoding='EUC-KR') as f:
    for line in f:
         #print(line)
        csv_data.append(my_split(line))
        
print(csv_data[:3])
# Out:
# [['로컬푸드인증번호', '인증유효시작일자', '인증유효종료일자', '인증취소일자', '사업장도로명주소', '사업장지번주소', '생산지도로명주소', '생산지지번주소', '품목명', '재배면적', '재배규모', '인증부여일자', '사업자명', '사업자등록번호', '전화번호', '관리기관명', '데이터기준일자', '제공기관코드', '제공기관명\n'], ['HYG-162', '2021-09-01', '2031-09-01', '', '경상남도 함양군 수동면 산업단지길 209+경상남도 함양군 수동면 우명하교로 174', '', '경상남도 함양군 병곡면 다볕길 94', '', '칡청+달맞이꽃씨유', '', '122', '2021-09-01', '청운당농산', '', '070-7779-2122', '경상남도 함양군청', '2022-11-23', '5460000', '경상남도 함양군\n'], ['HYG-163', '2021-09-01', '2031-09-01', '', '경상남도 함양군 수동면 산업단지길 209+경상남도 함양군 수동면 우명하교로 174', '', '경상남도 함양군 수동면 사근산성길 35-4', '', '굼벵이환', '', '123', '2021-09-01', '굼찬농장', '', '070-7779-2122', '경상남도 함양군청', '2022-11-23', '5460000', '경상남도 함양군\n']]

# %%
p1 = []
csv_data = csv_data[1:]
for i in csv_data:
    p1.append(i)

print(p1[:3])
# Out:
# [['HYG-166', '2021-09-01', '2031-09-01', '', '경상남도 함양군 수동면 산업단지길 209+경상남도 함양군 수동면 우명하교로 174', '', '경상남도 함양군 서하면 오현길 9', '', '포도', '', '126', '2021-09-01', '박영자', '', '070-7779-2122', '경상남도 함양군청', '2022-11-23', '5460000', '경상남도 함양군\n'], ['HYG-167', '2021-09-01', '2031-09-01', '', '경상남도 함양군 수동면 산업단지길 209+경상남도 함양군 수동면 우명하교로 174', '', '경상남도 함양군 안의면 종로길 24-2', '', '꿀', '', '127', '2021-09-01', '이화인양봉', '', '070-7779-2122', '경상남도 함양군청', '2022-11-23', '5460000', '경상남도 함양군\n'], ['HYG-168', '2021-09-01', '2031-09-01', '', '경상남도 함양군 수동면 산업단지길 209+경상남도 함양군 수동면 우명하교로 174', '', '경상남도 함양군 안의면 중동길 24', '', '포도', '', '128', '2021-09-01', '이상식', '', '070-7779-2122', '경상남도 함양군청', '2022-11-23', '5460000', '경상남도 함양군\n']]

# %%
p2 = []
for e in p1:
    y = e[15].split()
    y.append(e[8])
    p2.append(y)
print(p2[:100])
# Out:
# [['경상남도', '함양군청', '포도'], ['경상남도', '함양군청', '꿀'], ['경상남도', '함양군청', '포도'], ['경상남도', '함양군청', '사과'], ['경상남도', '함양군청', '샤인머스켓'], ['경상남도', '함양군청', '미숫가루'], ['경상남도', '함양군청', '밀가루+쌀'], ['경상남도', '함양군청', '사과'], ['경상남도', '함양군청', '알밤'], ['경상남도', '함양군청', '한라봉+레드향+천혜향'], ['경상남도', '함양군청', '사과'], ['경상남도', '함양군청', '서복태'], ['경상남도', '함양군청', '함양애주+지리산애주'], ['경상남도', '함양군청', '키고리+스카프+가방+두건'], ['경상남도', '함양군청', '로메인 상추'], ['경상남도', '함양군청', '더덕주'], ['경상남도', '함양군청', '블루베리'], ['경상남도', '함양군청', '호두'], ['경상남도', '함양군청', '새싹인삼'], ['경상남도', '함양군청', '유정란'], ['경상남도', '함양군청', '한과'], ['경상남도', '함양군청', '도라지'], ['경상남도', '함양군청', '곶감+감말랭이'], ['경상남도', '함양군청', '딸기'], ['경상남도', '함양군청', '고로쇠 수액'], ['경상남도', '함양군청', '지리산도라지와돌배'], ['경상남도', '함양군청', '곶감+말랭이+사과'], ['경상남도', '함양군청', '딸기+복수박'], ['경상남도', '함양군청', '두릅+고사리+취나물+누른호박'], ['경상남도', '함양군청', '배'], ['경상남도', '함양군청', '즙류+ABC주스+우슬진액'], ['경상남도', '함양군청', '꿀류'], ['경상남도', '함양군청', '차류'], ['경상남도', '함양군청', '미나리'], ['경상남도', '함양군청', '두릅+취나물'], ['경상남도', '함양군청', '머위즙+삼백초즙'], ['경상남도', '함양군청', '블루베리'], ['경상남도', '함양군청', '신령호두'], ['경상남도', '함양군청', '부각류'], ['경상남도', '함양군청', '블루베리'], ['경상남도', '함양군청', '가지+애호박'], ['경상남도', '함양군청', '사과'], ['경상남도', '함양군청', '차류'], ['경상남도', '함양군청', '아스파라거스'], ['경상남도', '함양군청', '담솔+복분자+솔송주'], ['경상남도', '함양군청', '고구마+사과'], ['경상남도', '함양군청', '도마+주걱'], ['경상남도', '함양군청', '약초류'], ['경상남도', '함양군청', '유기농계란'], ['경상남도', '함양군청', '엉겅퀴+오가피'], ['경상남도', '함양군청', '죽염류+된장+치약'], ['경상남도', '함양군청', '국화분재'], ['경상남도', '함양군청', '표고버섯'], ['경상남도', '함양군청', '도라지'], ['경상남도', '함양군청', '부각류'], ['경기도', '화성시청', '옥수수'], ['경상남도', '함양군청', '그린하미과+컬리플라워'], ['경상남도', '함양군청', '생강청+산골편강+도라비배청'], ['경상남도', '함양군청', '보리새싹'], ['경상남도', '함양군청', '레몬머틀'], ['경상남도', '함양군청', '배'], ['경상남도', '함양군청', '고구마+오란다+조청산자+김부각+강정류'], ['경상남도', '함양군청', '꿀류+곶감'], ['경상남도', '함양군청', '대파+양상추'], ['경상남도', '함양군청', '곶감'], ['경상남도', '함양군청', '사과'], ['경상남도', '함양군청', '사과즙+오미자청+도라지배즙'], ['경상남도', '함양군청', '고구마+무말랭이+시래기'], ['경상남도', '함양군청', '사과+사과즙'], ['경상남도', '함양군청', '반쯤깐밤'], ['경상남도', '함양군청', '산삼캔디'], ['경상남도', '함양군청', '지리산명월초 티백차'], ['경상남도', '함양군청', '표고버섯'], ['경상남도', '함양군청', '우산고로쇠 수액'], ['경상남도', '함양군청', '본래족발스페셜세트'], ['경상남도', '함양군청', '이불+베개+목화솜'], ['경상남도', '함양군청', '꾸찌봉차+꾸지뽕진액'], ['경상남도', '함양군청', '오미자즙+양파즙'], ['경상남도', '함양군청', '매실원액+개복숭아원액+솔순원액'], ['경상남도', '함양군청', '고로쇠 수액'], ['경상남도', '함양군청', '달걀'], ['경상남도', '함양군청', '꿀+화분'], ['경상남도', '함양군청', '아스파라거스'], ['경상남도', '함양군청', '꿀류'], ['경상남도', '함양군청', '고구마'], ['경상남도', '함양군청', '산삼캔디+산삼젤리'], ['경상남도', '함양군청', '곡물강정+산삼견과정+오미자랑'], ['경상남도', '함양군청', '고추부각+김부각'], ['경상남도', '함양군청', '고추장+된장+간장'], ['경상남도', '함양군청', '사과'], ['경상남도', '함양군청', '국수+마스크팩+샴푸+산삼주'], ['경상남도', '함양군청', '무말랭이+아주까리잎+토마토+열매마'], ['경상남도', '함양군청', '지리산 배도라지 생강청'], ['경상남도', '함양군청', '백봉령'], ['경상남도', '함양군청', '도라지'], ['경상남도', '함양군청', '산머루즙골드'], ['경상남도', '함양군청', '블루베리진액+상황버섯진액'], ['경상남도', '함양군청', '하늘과맞닿은 사과즙 도라지배즙'], ['경상남도', '함양군청', '냉동산딸기'], ['경상남도', '함양군청', '적양파+양파']]

# %%
p3 = []
for s in p2:
    for i, e in enumerate(s):
        s[i] = e.replace("+", ",")
    p3.append(s)
print(p3[:20])
# Out:
# [['경상남도', '함양군청', '포도'], ['경상남도', '함양군청', '꿀'], ['경상남도', '함양군청', '포도'], ['경상남도', '함양군청', '사과'], ['경상남도', '함양군청', '샤인머스켓'], ['경상남도', '함양군청', '미숫가루'], ['경상남도', '함양군청', '밀가루,쌀'], ['경상남도', '함양군청', '사과'], ['경상남도', '함양군청', '알밤'], ['경상남도', '함양군청', '한라봉,레드향,천혜향'], ['경상남도', '함양군청', '사과'], ['경상남도', '함양군청', '서복태'], ['경상남도', '함양군청', '함양애주,지리산애주'], ['경상남도', '함양군청', '키고리,스카프,가방,두건'], ['경상남도', '함양군청', '로메인 상추'], ['경상남도', '함양군청', '더덕주'], ['경상남도', '함양군청', '블루베리'], ['경상남도', '함양군청', '호두'], ['경상남도', '함양군청', '새싹인삼'], ['경상남도', '함양군청', '유정란']]

# %%
p4 = []
for i in p3:
    if len(i) >= 3:
        x = i[0] + ' ' + i[1]
        y = i[2]
        p4.append([x, y])
#print(p4)
# Out:
# [['경상남도 함양군청', '포도'], ['경상남도 함양군청', '꿀'], ['경상남도 함양군청', '포도'], ['경상남도 함양군청', '사과'], ['경상남도 함양군청', '샤인머스켓'], ['경상남도 함양군청', '미숫가루'], ['경상남도 함양군청', '밀가루,쌀'], ['경상남도 함양군청', '사과'], ['경상남도 함양군청', '알밤'], ['경상남도 함양군청', '한라봉,레드향,천혜향'], ['경상남도 함양군청', '사과'], ['경상남도 함양군청', '서복태'], ['경상남도 함양군청', '함양애주,지리산애주'], ['경상남도 함양군청', '키고리,스카프,가방,두건'], ['경상남도 함양군청', '로메인 상추'], ['경상남도 함양군청', '더덕주'], ['경상남도 함양군청', '블루베리'], ['경상남도 함양군청', '호두'], ['경상남도 함양군청', '새싹인삼'], ['경상남도 함양군청', '유정란'], ['경상남도 함양군청', '한과'], ['경상남도 함양군청', '도라지'], ['경상남도 함양군청', '곶감,감말랭이'], ['경상남도 함양군청', '딸기'], ['경상남도 함양군청', '고로쇠 수액'], ['경상남도 함양군청', '지리산도라지와돌배'], ['경상남도 함양군청', '곶감,말랭이,사과'], ['경상남도 함양군청', '딸기,복수박'], ['경상남도 함양군청', '두릅,고사리,취나물,누른호박'], ['경상남도 함양군청', '배'], ['경상남도 함양군청', '즙류,ABC주스,우슬진액'], ['경상남도 함양군청', '꿀류'], ['경상남도 함양군청', '차류'], ['경상남도 함양군청', '미나리'], ['경상남도 함양군청', '두릅,취나물'], ['경상남도 함양군청', '머위즙,삼백초즙'], ['경상남도 함양군청', '블루베리'], ['경상남도 함양군청', '신령호두'], ['경상남도 함양군청', '부각류'], ['경상남도 함양군청', '블루베리'], ['경상남도 함양군청', '가지,애호박'], ['경상남도 함양군청', '사과'], ['경상남도 함양군청', '차류'], ['경상남도 함양군청', '아스파라거스'], ['경상남도 함양군청', '담솔,복분자,솔송주'], ['경상남도 함양군청', '고구마,사과'], ['경상남도 함양군청', '도마,주걱'], ['경상남도 함양군청', '약초류'], ['경상남도 함양군청', '유기농계란'], ['경상남도 함양군청', '엉겅퀴,오가피'], ['경상남도 함양군청', '죽염류,된장,치약'], ['경상남도 함양군청', '국화분재'], ['경상남도 함양군청', '표고버섯'], ['경상남도 함양군청', '도라지'], ['경상남도 함양군청', '부각류'], ['경기도 화성시청', '옥수수'], ['경상남도 함양군청', '그린하미과,컬리플라워'], ['경상남도 함양군청', '생강청,산골편강,도라비배청'], ['경상남도 함양군청', '보리새싹'], ['경상남도 함양군청', '레몬머틀'], ['경상남도 함양군청', '배'], ['경상남도 함양군청', '고구마,오란다,조청산자,김부각,강정류'], ['경상남도 함양군청', '꿀류,곶감'], ['경상남도 함양군청', '대파,양상추'], ['경상남도 함양군청', '곶감'], ['경상남도 함양군청', '사과'], ['경상남도 함양군청', '사과즙,오미자청,도라지배즙'], ['경상남도 함양군청', '고구마,무말랭이,시래기'], ['경상남도 함양군청', '사과,사과즙'], ['경상남도 함양군청', '반쯤깐밤'], ['경상남도 함양군청', '산삼캔디'], ['경상남도 함양군청', '지리산명월초 티백차'], ['경상남도 함양군청', '표고버섯'], ['경상남도 함양군청', '우산고로쇠 수액'], ['경상남도 함양군청', '본래족발스페셜세트'], ['경상남도 함양군청', '이불,베개,목화솜'], ['경상남도 함양군청', '꾸찌봉차,꾸지뽕진액'], ['경상남도 함양군청', '오미자즙,양파즙'], ['경상남도 함양군청', '매실원액,개복숭아원액,솔순원액'], ['경상남도 함양군청', '고로쇠 수액'], ['경상남도 함양군청', '달걀'], ['경상남도 함양군청', '꿀,화분'], ['경상남도 함양군청', '아스파라거스'], ['경상남도 함양군청', '꿀류'], ['경상남도 함양군청', '고구마'], ['경상남도 함양군청', '산삼캔디,산삼젤리'], ['경상남도 함양군청', '곡물강정,산삼견과정,오미자랑'], ['경상남도 함양군청', '고추부각,김부각'], ['경상남도 함양군청', '고추장,된장,간장'], ['경상남도 함양군청', '사과'], ['경상남도 함양군청', '국수,마스크팩,샴푸,산삼주'], ['경상남도 함양군청', '무말랭이,아주까리잎,토마토,열매마'], ['경상남도 함양군청', '지리산 배도라지 생강청'], ['경상남도 함양군청', '백봉령'], ['경상남도 함양군청', '도라지'], ['경상남도 함양군청', '산머루즙골드'], ['경상남도 함양군청', '블루베리진액,상황버섯진액'], ['경상남도 함양군청', '하늘과맞닿은 사과즙 도라지배즙'], ['경상남도 함양군청', '냉동산딸기'], ['경상남도 함양군청', '적양파,양파'], ['경상남도 함양군청', '감자'], ['경상남도 함양군청', '수박'], ['경상남도 함양군청', '지리산 꾸찌봉잎차'], ['경기도 화성시청', '산딸기'], ['경기도 화성시청', '"마늘, 열무, 양파"'], ['경기도 화성시청', '"치커리, 상추, 열무, 배추, 호박, 대파, 호박잎"'], ['경기도 화성시청', '"마늘, 고추"'], ['경기도 화성시청', '"고추, 마늘"'], ['경기도 화성시청', '"마늘, 양파"'], ['경기도 화성시청', '포도'], ['경기도 화성시청', '블루베리'], ['경기도 화성시청', '블루베리'], ['경기도 화성시청', '복숭아'], ['경기도 화성시청', '토종빨강강낭콩'], ['경기도 화성시청', '고추'], ['경기도 화성시청', '새송이'], ['경기도 화성시청', '감자'], ['경기도 화성시청', '완두'], ['경기도 화성시청', '"살구, 복숭아"'], ['경기도 화성시청', '당근'], ['경기도 화성시청', '노각오이'], ['경기도 화성시청', '"바이오체리, 사과대추"'], ['경기도 화성시청', '"들깻잎, 참외, 토마토, 호박, 오이, 고추, 대파"'], ['경기도 화성시청', '대파'], ['경기도 화성시청', '메리골드'], ['경기도 화성시청', '블루베리'], ['경기도 화성시청', '"참외, 고추, 들깻잎"'], ['경기도 화성시청', '포도'], ['경기도 화성시청', '"가리비, 굴"'], ['경기도 화성시청', '옥수수'], ['경기도 화성시청', '포도'], ['경기도 화성시청', '포도'], ['경기도 화성시청', '"개구리참외, 복수박, 사과참외, 들깻잎"'], ['경기도 화성시청', '고추'], ['경기도 화성시청', '딸기'], ['경기도 화성시청', '토마토,오이'], ['경기도 화성시청', '목이'], ['경기도 화성시청', '아스파라거스'], ['경기도 화성시청', '아스파라거스'], ['경기도 화성시청', '표고'], ['경기도 화성시청', '체리'], ['경기도 화성시청', '아스파라거스'], ['경기도 화성시청', '표고'], ['경기도 화성시청', '감자'], ['경기도 화성시청', '"감자, 고구마"'], ['경기도 화성시청', '감자'], ['경기도 화성시청', '마늘'], ['경기도 화성시청', '"토마토, 방울토마토, 양파"'], ['경기도 화성시청', '감자'], ['경기도 화성시청', '블루베리'], ['경기도 화성시청', '블루베리'], ['경기도 화성시청', '오디'], ['경기도 화성시청', '오디'], ['경기도 화성시청', '마늘'], ['경기도 화성시청', '"마늘, 양파, 고수"'], ['경기도 화성시청', '홍감자'], ['경기도 화성시청', '감자'], ['경기도 화성시청', '블루베리'], ['경기도 화성시청', '감자'], ['경기도 화성시청', '감자'], ['경기도 화성시청', '감자'], ['경기도 화성시청', '감자'], ['경기도 화성시청', '"감자,  ...

# %%
v = np.array(p4)
print(v[:100])
# Out:
# [['경상남도 함양군청' '포도']
#  ['경상남도 함양군청' '꿀']
#  ['경상남도 함양군청' '포도']
#  ['경상남도 함양군청' '사과']
#  ['경상남도 함양군청' '샤인머스켓']
#  ['경상남도 함양군청' '미숫가루']
#  ['경상남도 함양군청' '밀가루,쌀']
#  ['경상남도 함양군청' '사과']
#  ['경상남도 함양군청' '알밤']
#  ['경상남도 함양군청' '한라봉,레드향,천혜향']
#  ['경상남도 함양군청' '사과']
#  ['경상남도 함양군청' '서복태']
#  ['경상남도 함양군청' '함양애주,지리산애주']
#  ['경상남도 함양군청' '키고리,스카프,가방,두건']
#  ['경상남도 함양군청' '로메인 상추']
#  ['경상남도 함양군청' '더덕주']
#  ['경상남도 함양군청' '블루베리']
#  ['경상남도 함양군청' '호두']
#  ['경상남도 함양군청' '새싹인삼']
#  ['경상남도 함양군청' '유정란']
#  ['경상남도 함양군청' '한과']
#  ['경상남도 함양군청' '도라지']
#  ['경상남도 함양군청' '곶감,감말랭이']
#  ['경상남도 함양군청' '딸기']
#  ['경상남도 함양군청' '고로쇠 수액']
#  ['경상남도 함양군청' '지리산도라지와돌배']
#  ['경상남도 함양군청' '곶감,말랭이,사과']
#  ['경상남도 함양군청' '딸기,복수박']
#  ['경상남도 함양군청' '두릅,고사리,취나물,누른호박']
#  ['경상남도 함양군청' '배']
#  ['경상남도 함양군청' '즙류,ABC주스,우슬진액']
#  ['경상남도 함양군청' '꿀류']
#  ['경상남도 함양군청' '차류']
#  ['경상남도 함양군청' '미나리']
#  ['경상남도 함양군청' '두릅,취나물']
#  ['경상남도 함양군청' '머위즙,삼백초즙']
#  ['경상남도 함양군청' '블루베리']
#  ['경상남도 함양군청' '신령호두']
#  ['경상남도 함양군청' '부각류']
#  ['경상남도 함양군청' '블루베리']
#  ['경상남도 함양군청' '가지,애호박']
#  ['경상남도 함양군청' '사과']
#  ['경상남도 함양군청' '차류']
#  ['경상남도 함양군청' '아스파라거스']
#  ['경상남도 함양군청' '담솔,복분자,솔송주']
#  ['경상남도 함양군청' '고구마,사과']
#  ['경상남도 함양군청' '도마,주걱']
#  ['경상남도 함양군청' '약초류']
#  ['경상남도 함양군청' '유기농계란']
#  ['경상남도 함양군청' '엉겅퀴,오가피']
#  ['경상남도 함양군청' '죽염류,된장,치약']
#  ['경상남도 함양군청' '국화분재']
#  ['경상남도 함양군청' '표고버섯']
#  ['경상남도 함양군청' '도라지']
#  ['경상남도 함양군청' '부각류']
#  ['경기도 화성시청' '옥수수']
#  ['경상남도 함양군청' '그린하미과,컬리플라워']
#  ['경상남도 함양군청' '생강청,산골편강,도라비배청']
#  ['경상남도 함양군청' '보리새싹']
#  ['경상남도 함양군청' '레몬머틀']
#  ['경상남도 함양군청' '배']
#  ['경상남도 함양군청' '고구마,오란다,조청산자,김부각,강정류']
#  ['경상남도 함양군청' '꿀류,곶감']
#  ['경상남도 함양군청' '대파,양상추']
#  ['경상남도 함양군청' '곶감']
#  ['경상남도 함양군청' '사과']
#  ['경상남도 함양군청' '사과즙,오미자청,도라지배즙']
#  ['경상남도 함양군청' '고구마,무말랭이,시래기']
#  ['경상남도 함양군청' '사과,사과즙']
#  ['경상남도 함양군청' '반쯤깐밤']
#  ['경상남도 함양군청' '산삼캔디']
#  ['경상남도 함양군청' '지리산명월초 티백차']
#  ['경상남도 함양군청' '표고버섯']
#  ['경상남도 함양군청' '우산고로쇠 수액']
#  ['경상남도 함양군청' '본래족발스페셜세트']
#  ['경상남도 함양군청' '이불,베개,목화솜']
#  ['경상남도 함양군청' '꾸찌봉차,꾸지뽕진액']
#  ['경상남도 함양군청' '오미자즙,양파즙']
#  ['경상남도 함양군청' '매실원액,개복숭아원액,솔순원액']
#  ['경상남도 함양군청' '고로쇠 수액']
#  ['경상남도 함양군청' '달걀']
#  ['경상남도 함양군청' '꿀,화분']
#  ['경상남도 함양군청' '아스파라거스']
#  ['경상남도 함양군청' '꿀류']
#  ['경상남도 함양군청' '고구마']
#  ['경상남도 함양군청' '산삼캔디,산삼젤리']
#  ['경상남도 함양군청' '곡물강정,산삼견과정,오미자랑']
#  ['경상남도 함양군청' '고추부각,김부각']
#  ['경상남도 함양군청' '고추장,된장,간장']
#  ['경상남도 함양군청' '사과']
#  ['경상남도 함양군청' '국수,마스크팩,샴푸,산삼주']
#  ['경상남도 함양군청' '무말랭이,아주까리잎,토마토,열매마']
#  ['경상남도 함양군청' '지리산 배도라지 생강청']
#  ['경상남도 함양군청' '백봉령']
#  ['경상남도 함양군청' '도라지']
#  ['경상남도 함양군청' '산머루즙골드']
#  ['경상남도 함양군청' '블루베리진액,상황버섯진액']
#  ['경상남도 함양군청' '하늘과맞닿은 사과즙 도라지배즙']
#  ['경상남도 함양군청' '냉동산딸기']
#  ['경상남도 함양군청' '적양파,양파']]
